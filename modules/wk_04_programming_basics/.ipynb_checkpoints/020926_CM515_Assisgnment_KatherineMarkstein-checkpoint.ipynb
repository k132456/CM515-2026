# %% [markdown]
# # CM515 Intro to Python Assignment - February 9th, 2026
#
# ## For each question, please write your code in an organized format based on the grammar guidelines discussed in class.
# ## If you use AI assistance for a question, please explain how you used it to help you.
# ## Submit your assignment on Canvas as a .ipynb file.
#
#
# Point value
#
# Q1 - 1 pt.
#
# Q2 - 2pt. (1pt. for the variable assignments, 1pt. for the print statement)
#
# Q3 - 3pt. (1pt. for the variable assignment, 1pt. for indexing, 1pt. for making the variable)
#
# Q4 - 3pt. (1pt. for the variable assignment, 1pt. for the first statement, 1pt. for the second statement)
#
# Q5 - 2pt. (1pt. for the variable assignemnt, 1pt. for the f-string)
#
# Q6 - 3pt. (1pt. for the variable assignment, 1pt. for the f-string, 1pt. for converting variables to inputs)

# %% [markdown]
# ## 1.Print the following statement: `This assignment is so easy!`

# %%
print ("This assignment is so easy!")
# Out:
# This assignment is so easy!

# %% [markdown]
# ## 2. Create several variables that each represent an individual letter. Combine the variables in a print statement to spell Python.

# %%
a = 'P'
b = 'y'
c = 't'
d = 'h'
e = 'o'
f = 'n'
print (a+b+c+d+e+f)
# Out:
# Python

# %% [markdown]
# ## 3. Create a variable `alphabet` that contains the alphabet. Use indexing to find the letters that make up your first name. Make a variable `Name` that spells your first name using the index. Print your name using the variable.

# %%
alphabet = 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'

name = alphabet[10] + alphabet[0] + alphabet[19] + alphabet [8] + alphabet[4]
print (name)
# Out:
# KATIE

# %% [markdown]
# ## 4.Create a variable `numbers` that has the numbers 1-9 in a row. Print a statement with only the odd numbers. Print a second statement with only the even numbers.

# %%
numbers = "123456789"

print(numbers[0:9:2])
print(numbers[1:8:2])
# Out:
# 13579
# 2468

# %% [markdown]
# ## 5.
# We can calculate yearly interest using the following equation:
#
# `total = principle amount * interest(a percentage) * time (usually in years)`
#
# Your goal is to print a statement that explains how much money you would make if you had $10,000 as the principle amount in a savings account after a year with 4% interest.
#
# Generate the following numeric variables: `principle`, `interest`, `years`, `total`.
#
# Your printed string should look something like this:
#
# `If I put $`principle` in a savings account with an annual interest rate of `interest`%, after `years` years I would have made $`total`.`
#
# *In this case we are assuming the interest is not compounding. After next week you will have the knowledge to make a script to account for compounding interest.*

# %%
principle = 10000

interest = 4.0

years = 1

total = principle * (interest/100) * years



print (f"If I put ${principle} in a savings account with an annual interest rate of {interest_percent}%, after {years} year I would have made ${total} total.")
# Out:
# If I put $10000 in a savings account with an annual interest rate of 4.0%, after 1 year I would have made $400.0 total.

# %% [markdown]
# # 6. Rework the code from question number 5 such that instead of assigning values, you are asked to input the values for your principle, interest, and years variables every time you run the script.
#
# *Helpful Hint: `input()` takes only a string argument. How will you calculate the total if a of your variables are strings?*

# %%
principle = input("What is the principle amount of money in the account?")
principle = int(principle)

interest = input("What is the annual interest rate?")
interest = int(interest)

years = input("How long has the account been open, in years?")
years = int(years)

total = principle * (interest/100) * years

print (f"If I put ${principle} in a savings account with an annual interest rate of {interest}, after {years} years I would have made ${total}.")
# Out:
# What is the principle amount of money in the account? 10000
# What is the annual interest rate? 4
# How long has the account been open, in years? 1
# If I put $10000 in a savings account with an annual interest rate of 4, after 1 years I would have made $400.0.
